# %%
import pandas as pd
import requests

# %%
data_set = catalog.load('shots_train')   
data_set.head()
# Out:
# [03/31/25 17:06:02] INFO     Loading data from shots_train (ParquetDataset)...                  ]8;id=398585;file://C:\ProgramData\anaconda3\envs\kedro_env\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=739642;file://C:\ProgramData\anaconda3\envs\kedro_env\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#            lat       lon  minutes_remaining  period  playoffs  shot_distance  \
# 7006   34.0343 -118.1288                  1       2         0             14
# 20760  33.9723 -118.0808                  0       3         0             20
# 15143  33.8713 -118.1728                 11       3         0             19
# 10506  34.0443 -118.2698                 11       2         0              0
# 21377  33.8543 -118.2698                 11       3         0             19
#
#        loc_x  loc_y  shot_made_flag
# ...

# %%
data_set_prod = catalog.load('data_features_prod')   

if 'shot_made_flag' in data_set_prod.columns:
    data_set_prod = data_set_prod.drop(columns=['shot_made_flag'])
    print("Coluna 'shot_made_flag' removida do dataset de produção.")

model_columns = list(data_set_prod.columns)
data = {
    "dataframe_split": {
        "columns": model_columns,
        "data": data_set_prod.values.tolist()
    }
}

response = requests.post(
    "http://localhost:5001/invocations",
    headers={"Content-Type": "application/json"},
    json=data
)

print(response.json())
# Out:
# [03/31/25 17:09:20] INFO     Loading data from data_features_prod (ParquetDataset)...           ]8;id=698922;file://C:\ProgramData\anaconda3\envs\kedro_env\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=162102;file://C:\ProgramData\anaconda3\envs\kedro_env\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\
# Coluna 'shot_made_flag' removida do dataset de produção.
# ...
